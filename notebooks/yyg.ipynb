# %%
# Install a Drive FUSE wrapper.
# https://github.com/astrada/google-drive-ocamlfuse
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
# Generate auth tokens for Colab
from google.colab import auth
auth.authenticate_user()
# Generate creds for the Drive FUSE library.
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Create a directory and mount Google Drive using that directory.
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144579 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.22-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.22-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.22-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# ...

# %%
# %cd drive/yyg-seir-simulator-master
# %ls
# Out:
# /content/drive/yyg-seir-simulator-master
# best_params/                     mortality_timeseries_prov.csv  simulation.py
# fixed_params.py                  __pycache__/                   utils.py
# learn_simulation.py              README.md                      yyg.ipynb
# LICENSE                          region_model.py
# mortality_timeseries_canada.csv  run_simulation.py

# %%
# !python learn_simulation.py -v --best_params_dir best_params/latest --country Canada --subregion Ontario
# Out:
# ...
# YYG/C19PRO Simulator
# Current time: 2020-09-11 01:26:06.681819
# ...
# Loading params file: best_params/latest/subregion/Canada_Ontario.json
# best params type: mean
# ...
# Canada | ALL | Ontario
# ...
# Parameters:
# INITIAL_R_0               : 1.8621476756657092
# LOCKDOWN_R_0              : 0.8121886339025861
# INFLECTION_DAY            : 2020-03-27
# RATE_OF_INFLECTION        : 0.3497453946619491
# LOCKDOWN_FATIGUE          : 1.0
# DAILY_IMPORTS             : 194.06780757414793
# MORTALITY_RATE            : 0.012500000000000002
# REOPEN_DATE               : 2020-06-01
# REOPEN_SHIFT_DAYS         : 14.24962572681525
# REOPEN_R                  : 0.9350336996413784
# REOPEN_INFLECTION         : 0.30222943084385256
# POST_REOPEN_EQUILIBRIUM_R : 0.9875365749849131
# FALL_R_MULTIPLIER         : 1.0010158770538358
# --------------------------
# Running simulation...
# --------------------------
# Finding new optimum with error: 181147.71450687552
# Finding new optimum with error: 171527.99249718405
# ...

# %%
# !python run_simulation.py -v --best_params_dir best_params/latest --country Canada --subregion Ontario
# Out:
# ...
# YYG/C19PRO Simulator
# Current time: 2020-09-09 03:11:52.256277
# ...
# Loading params file: best_params/latest/subregion/Canada_Ontario.json
# best params type: mean
# ...
# Canada | ALL | Ontario
# ...
# Parameters:
# INITIAL_R_0               : 1.831148587560183
# LOCKDOWN_R_0              : 0.8311408009589307
# INFLECTION_DAY            : 2020-03-27
# RATE_OF_INFLECTION        : 0.3484517076802614
# LOCKDOWN_FATIGUE          : 1.0
# DAILY_IMPORTS             : 191.430557425032
# MORTALITY_RATE            : 0.0125
# REOPEN_DATE               : 2020-06-01
# REOPEN_SHIFT_DAYS         : 14.283089254380334
# REOPEN_R                  : 0.943939075892272
# REOPEN_INFLECTION         : 0.30265905984868713
# POST_REOPEN_EQUILIBRIUM_R : 1.0045576450704634
# FALL_R_MULTIPLIER         : 1.0010217105903934
# --------------------------
# Running simulation...
# --------------------------
# ...

# %%
# !python run_simulation.py -v --best_params_dir best_params/latest --country Canada --subregion Quebec
# Out:
# ...
# YYG/C19PRO Simulator
# Current time: 2020-09-09 03:12:45.207739
# ...
# Loading params file: best_params/latest/subregion/Canada_Quebec.json
# best params type: mean
# ...
# Canada | ALL | Quebec
# ...
# Parameters:
# INITIAL_R_0               : 2.026472931235465
# LOCKDOWN_R_0              : 0.8682867607281523
# INFLECTION_DAY            : 2020-03-27
# RATE_OF_INFLECTION        : 0.3296639097724995
# LOCKDOWN_FATIGUE          : 1.0
# DAILY_IMPORTS             : 200.35609056906435
# MORTALITY_RATE            : 0.0175
# REOPEN_DATE               : 2020-06-01
# REOPEN_SHIFT_DAYS         : 13.292926335305612
# REOPEN_R                  : 0.9048839534608819
# REOPEN_INFLECTION         : 0.29988720446833
# POST_REOPEN_EQUILIBRIUM_R : 1.0020942526912473
# FALL_R_MULTIPLIER         : 1.0008976695615392
# --------------------------
# Running simulation...
# --------------------------
# ...

# %%
# !python run_simulation.py -v --best_params_dir best_params/latest --country Canada --subregion "British Columbia"
# Out:
# ...
# YYG/C19PRO Simulator
# Current time: 2020-09-09 03:13:32.853403
# ...
# Loading params file: best_params/latest/subregion/Canada_British-Columbia.json
# best params type: mean
# ...
# Canada | ALL | British Columbia
# ...
# Parameters:
# INITIAL_R_0               : 1.138235294117647
# LOCKDOWN_R_0              : 0.7585784313725492
# INFLECTION_DAY            : 2020-03-23
# RATE_OF_INFLECTION        : 0.29732562025398646
# LOCKDOWN_FATIGUE          : 0.9999999999999998
# DAILY_IMPORTS             : 62.950980392156865
# MORTALITY_RATE            : 0.009999999999999997
# REOPEN_DATE               : 2020-05-19
# REOPEN_SHIFT_DAYS         : -0.0735294117647059
# REOPEN_R                  : 1.0443627450980393
# REOPEN_INFLECTION         : 0.3031862745098039
# POST_REOPEN_EQUILIBRIUM_R : 1.0077007368033755
# FALL_R_MULTIPLIER         : 1.0011799726028507
# --------------------------
# Running simulation...
# --------------------------
# ...

# %%
# !python run_simulation.py -v --best_params_dir best_params/latest --country Canada
# Out:
# ...
# YYG/C19PRO Simulator
# Current time: 2020-09-09 03:14:19.898595
# ...
# Loading params file: best_params/latest/global/Canada_ALL.json
# best params type: mean
# ...
# Canada | ALL |
# ...
# Parameters:
# INITIAL_R_0               : 1.9956159451559867
# LOCKDOWN_R_0              : 0.8518868988070065
# INFLECTION_DAY            : 2020-03-25
# RATE_OF_INFLECTION        : 0.17757308806644628
# LOCKDOWN_FATIGUE          : 1.0
# DAILY_IMPORTS             : 184.40270159877758
# MORTALITY_RATE            : 0.01
# REOPEN_DATE               : 2020-05-25
# REOPEN_SHIFT_DAYS         : 30.694492877735506
# REOPEN_R                  : 1.0527444311542342
# REOPEN_INFLECTION         : 0.2972552520436125
# POST_REOPEN_EQUILIBRIUM_R : 1.0029242850750326
# FALL_R_MULTIPLIER         : 1.0009293992839878
# --------------------------
# Running simulation...
# --------------------------
# ...

# %%
# !python run_simulation.py -v --best_params_dir best_params/latest --country US --region CA
# Out:
# ...
# YYG/C19PRO Simulator
# Current time: 2020-09-09 03:15:39.655143
# ...
# Loading params file: best_params/latest/US_CA.json
# best params type: mean
# ...
# US | CA |
# ...
# Parameters:
# INITIAL_R_0               : 1.7273075879700155
# LOCKDOWN_R_0              : 0.9748296471779917
# INFLECTION_DAY            : 2020-03-22
# RATE_OF_INFLECTION        : 0.2939539399811557
# LOCKDOWN_FATIGUE          : 0.9999999999999999
# DAILY_IMPORTS             : 162.6159486508543
# MORTALITY_RATE            : 0.007499999999999999
# REOPEN_DATE               : 2020-06-01
# REOPEN_SHIFT_DAYS         : -25.187372190401412
# REOPEN_R                  : 1.2504429134003057
# REOPEN_INFLECTION         : 0.26350449423019195
# POST_REOPEN_EQUILIBRIUM_R : 0.9994556690938415
# FALL_R_MULTIPLIER         : 1.0011392564087576
# --------------------------
# Running simulation...
# --------------------------
# ...

# %%
# !python run_simulation.py -v --best_params_dir best_params/latest --country US --region MI
# Out:
# ...
# YYG/C19PRO Simulator
# Current time: 2020-09-09 03:16:48.030289
# ...
# Loading params file: best_params/latest/US_MI.json
# best params type: mean
# ...
# US | MI |
# ...
# Parameters:
# INITIAL_R_0               : 2.025122986100512
# LOCKDOWN_R_0              : 0.7949443422591823
# INFLECTION_DAY            : 2020-03-14
# RATE_OF_INFLECTION        : 0.32588555343975645
# LOCKDOWN_FATIGUE          : 1.0
# DAILY_IMPORTS             : 935.4829601474249
# MORTALITY_RATE            : 0.012500000000000002
# REOPEN_DATE               : 2020-06-08
# REOPEN_SHIFT_DAYS         : -14.04989343731815
# REOPEN_R                  : 1.1841738185410235
# REOPEN_INFLECTION         : 0.3026976038520749
# POST_REOPEN_EQUILIBRIUM_R : 0.9903638148962051
# FALL_R_MULTIPLIER         : 1.001047279256361
# --------------------------
# Running simulation...
# --------------------------
# ...
